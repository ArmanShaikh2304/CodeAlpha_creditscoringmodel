# %% [markdown]
# # Credit Scoring Model Workflow
#
# This notebook provides an interactive entry point for loading the UCI German Credit dataset, inspecting the engineered features, and running the full training pipeline.

# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(project_root))

from src.data_loader import load_credit_dataset
from src.preprocessing import clean_credit_data, dataset_profile

df = clean_credit_data(load_credit_dataset())
df.head()

# %%
print(dataset_profile(df))

# %%
# Run the complete training, evaluation, and artifact-generation pipeline.
import runpy

runpy.run_path(str(project_root / "train.py"), run_name="__main__")
